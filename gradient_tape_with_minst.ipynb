# %% [markdown]
# #### Step 0: Project Setup

# %% [markdown]
# # Project: Custom Training with Gradient
# ### Objective:
# * Trian a neural network using GradientTape on mnist dataset
# ### Why Gradient Tape?
# * Enables custom loss functions, dynamic control and manual optimization steps

# %% [markdown]
# #### Step 1: Imports and Setup

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filter('ignore')
